# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product ">
# </a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="200" alt="cognitiveclass.ai logo">

# %% [markdown]
# <h1>Objective</h1><ul><li> How to create a dataset object.</li></ul>

# %% [markdown]
# <h1>Data Preparation with PyTorch</h1>

# %% [markdown]
# <p>Crack detection has vital importance for structural health monitoring and inspection. We would like to train a network to detect Cracks, we will denote the images that contain cracks as positive and images with no cracks as negative.  In this lab you are going to have to build a dataset object. There are five questions in this lab, Including some questions that are intermediate steps to help you build the dataset object. You are going to have to remember the output for some  of the questions. </p>

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#download_data"> Download data</a></li>
#     <li><a href="#examine_files">Examine Files</a></li>
#     <li><a href="#Question_1"><b>Question 1:find number of files</b> </a></li>
#     <li><a href="#assign_labels">Assign Labels to Images  </a></li>
#     <li><a href="#Question_2"><b>Question 2 : Assign labels to image </b> </a></li>
#     <li><a href="#split">Training  and Validation  Split </a></li>
#     <li><a href="#Question_3"><b>Question 3: Training  and Validation  Split</b> </a></li>
# <li><a href="#data_class">Create a Dataset Class </a></li>
#     <li><a href="#Question_4"><b>Question 4:Display  training dataset object</b> </a></li>
#     <li><a href="#Question_5"><b>Question 5:Display  validation dataset  object</b> </a></li>
#
# </ul>
# <p>Estimated Time Needed: <strong>25 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab:

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os
import glob
import torch
from torch.utils.data import Dataset
import skillsnetwork

# %% [markdown]
# We will use this function in the lab to plot:

# %%
def show_data(data_sample, shape = (28, 28)):
    plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
    plt.title('y = ' + data_sample[1])

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# In this section, you are going to download the data from IBM object storage using **skillsnetwork.prepare** command. <b>skillsnetwork.prepare</b> is a command that's used to download a zip file, unzip it and store it in a specified directory. Locally we store the data in the directory  **/resources/data**.

# %%
# await skillsnetwork.prepare("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip", path = "/resources/data", overwrite=True)

# %% [markdown]
# We then download the files that contain the negative images:

# %% [markdown]
# <h2 id="examine_files">Examine Files </h2>

# %% [markdown]
# In the previous lab, we create two lists; one to hold the path to the Negative files and one to hold the path to the Positive files. This process is shown in the following few lines of code.

# %% [markdown]
# We can obtain the list that contains the path to the <b>negative files</b> as follows:

# %%
directory="resources/data"
negative='Negative'
negative_file_path=os.path.join(directory,negative)
negative_files=[os.path.join(negative_file_path,file) for file in  os.listdir(negative_file_path) if file.endswith(".jpg")]
negative_files.sort()
negative_files[0:3]
# Out:
# ['resources/data/Negative/00001.jpg',
#  'resources/data/Negative/00002.jpg',
#  'resources/data/Negative/00003.jpg']

# %% [markdown]
# We can obtain the list that contains the path to the <b>positive files</b> files as follows:

# %%
positive="Positive"
positive_file_path=os.path.join(directory,positive)
positive_files=[os.path.join(positive_file_path,file) for file in  os.listdir(positive_file_path) if file.endswith(".jpg")]
positive_files.sort()
positive_files[0:3]
# Out:
# ['resources/data/Positive/00001.jpg',
#  'resources/data/Positive/00002.jpg',
#  'resources/data/Positive/00003.jpg']

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>
# <b>Find the <b>combined</b> length of the list <code>positive_files</code> and <code>negative_files</code> using the function <code>len</code> . Then assign  it to the variable <code>number_of_samples</code></b>

# %%
print(len(positive_files) + len(negative_files))
# Out:
# 40000

# %% [markdown]
# <h2 id="assign_labels">Assign Labels to Images </h2>

# %% [markdown]
# In this section we will assign a label to each image in this case we  can assign the positive images, i.e images with a crack to a value one  and the negative images i.e images with out a crack to a value of zero <b>Y</b>. First we create a tensor or vector of zeros, each element corresponds to a new sample. The length of the tensor is equal to the number of samples.

# %%
number_of_samples = len(positive_files) + len(negative_files)
Y=torch.zeros([number_of_samples])

# %% [markdown]
# As we are using the tensor <b>Y</b> for classification we cast it to a <code>LongTensor</code>.

# %%
Y=Y.type(torch.LongTensor)
Y.type()
# Out:
# 'torch.LongTensor'

# %% [markdown]
# With respect to each element we will set the even elements to class one and the odd elements to class zero.

# %%
Y[::2]=1
Y[1::2]=0

# %% [markdown]
# <h2 id="Question_2">Question 2</h2>
# <b>Create a list all_files such that the even indexes contain the path to images with positive or cracked samples and the odd element contain the negative images or images with out cracks. Then use the following code to print out the first four samples.</b>

# %%
all_files = list()
for i in range(0, len(positive_files)):
    all_files.append(positive_files[i])
    all_files.append(negative_files[i])

# %% [markdown]
# code used to print samples:

# %%
for y,file in zip(Y, all_files[0:4]):
    plt.imshow(Image.open(file))
    plt.title("y="+str(y.item()))
    plt.show()

# %% [markdown]
# <h2 id="split">Training  and Validation  Split  </h2>
# When training the model we  split up our data into training and validation data. It If the variable train is set to <code>True</code>  the following lines of code will segment the  tensor <b>Y</b> such at  the first 30000 samples are used for training. If the variable train is set to <code>False</code> the remainder of the samples will be used for validation data.

# %%
train=False

if train:
    all_files=all_files[0:30000]
    Y=Y[0:30000]

else:
    all_files=all_files[30000:]
    Y=Y[30000:]

# %% [markdown]
# <h2 id="Question_3">Question 3</h2>
# Modify the above lines of code such that if the variable <code>train</code> is set to <c>True</c> the first 30000 samples of all_files are use in training. If <code>train</code> is set to <code>False</code> the remaining  samples are used for validation. In both cases reassign  the values to the variable all_files, then use the following lines of code to print out the first four validation sample images.

# %%
all_files
# Out:
# ['resources/data/Positive/15001_1.jpg',
#  'resources/data/Negative/15001.jpg',
#  'resources/data/Positive/15002_1.jpg',
#  'resources/data/Negative/15002.jpg',
#  'resources/data/Positive/15003_1.jpg',
#  'resources/data/Negative/15003.jpg',
#  'resources/data/Positive/15004_1.jpg',
#  'resources/data/Negative/15004.jpg',
#  'resources/data/Positive/15005_1.jpg',
#  'resources/data/Negative/15005.jpg',
#  'resources/data/Positive/15006_1.jpg',
#  'resources/data/Negative/15006.jpg',
#  'resources/data/Positive/15007_1.jpg',
#  'resources/data/Negative/15007.jpg',
#  'resources/data/Positive/15008_1.jpg',
#  'resources/data/Negative/15008.jpg',
#  'resources/data/Positive/15009_1.jpg',
#  'resources/data/Negative/15009.jpg',
#  'resources/data/Positive/15010_1.jpg',
#  'resources/data/Negative/15010.jpg',
#  'resources/data/Positive/15011_1.jpg',
#  'resources/data/Negative/15011.jpg',
#  'resources/data/Positive/15012_1.jpg',
#  'resources/data/Negative/15012.jpg',
#  'resources/data/Positive/15013_1.jpg',
#  'resources/data/Negative/15013.jpg',
#  'resources/data/Positive/15014_1.jpg',
#  'resources/data/Negative/15014.jpg',
#  'resources/data/Positive/15015_1.jpg',
#  'resources/data/Negative/15015.jpg',
#  'resources/data/Positive/15016_1.jpg',
#  'resources/data/Negative/15016.jpg',
#  'resources/data/Positive/15017_1.jpg',
#  'resources/data/Negative/15017.jpg',
#  'resources/data/Positive/15018_1.jpg',
#  'resources/data/Negative/15018.jpg',
#  'resources/data/Positive/15019_1.jpg',
#  'resources/data/Negative/15019.jpg',
#  'resources/data/Positive/15020_1.jpg',
#  'resources/data/Negative/15020.jpg',
#  'resources/data/Positive/15021_1.jpg',
#  'resources/data/Negative/15021.jpg',
#  'resources/data/Positive/15022_1.jpg',
#  'resources/data/Negative/15022.jpg',
#  'resources/data/Positive/15023_1.jpg',
#  'resources/data/Negative/15023.jpg',
#  'resources/data/Positive/15024_1.jpg',
#  'resources/data/Negative/15024.jpg',
#  'resources/data/Positive/15025_1.jpg',
#  'resources/data/Negative/15025.jpg',
#  'resources/data/Positive/15026_1.jpg',
#  'resources/data/Negative/15026.jpg',
#  'resources/data/Positive/15027_1.jpg',
#  'resources/data/Negative/15027.jpg',
#  'resources/data/Positive/15028_1.jpg',
#  'resources/data/Negative/15028.jpg',
#  'resources/data/Positive/15029_1.jpg',
#  'resources/data/Negative/15029.jpg',
#  'resources/data/Positive/15030_1.jpg',
#  'resources/data/Negative/15030.jpg',
#  'resources/data/Positive/15031_1.jpg',
#  'resources/data/Negative/15031.jpg',
#  'resources/data/Positive/15032_1.jpg',
#  'resources/data/Negative/15032.jpg',
#  'resources/data/Positive/15033_1.jpg',
#  'resources/data/Negative/15033.jpg',
#  'resources/data/Positive/15034_1.jpg',
#  'resources/data/Negative/15034.jpg',
#  'resources/data/Positive/15035_1.jpg',
#  'resources/data/Negative/15035.jpg',
#  'resources/data/Positive/15036_1.jpg',
#  'resources/data/Negative/15036.jpg',
#  'resources/data/Positive/15037_1.jpg',
#  'resources/data/Negative/15037.jpg',
#  'resources/data/Positive/15038_1.jpg',
#  'resources/data/Negative/15038.jpg',
#  'resources/data/Positive/15039_1.jpg',
#  'resources/data/Negative/15039.jpg',
#  'resources/data/Positive/15040_1.jpg',
#  'resources/data/Negative/15040.jpg',
#  'resources/data/Positive/15041_1.jpg',
#  'resources/data/Negative/15041.jpg',
#  'resources/data/Positive/15042_1.jpg',
#  'resources/data/Negative/15042.jpg',
#  'resources/data/Positive/15043_1.jpg',
#  'resources/data/Negative/15043.jpg',
#  'resources/data/Positive/15044_1.jpg',
#  'resources/data/Negative/15044.jpg',
#  'resources/data/Positive/15045_1.jpg',
#  'resources/data/Negative/15045.jpg',
#  'resources/data/Positive/15046_1.jpg',
#  'resources/data/Negative/15046.jpg',
#  'resources/data/Positive/15047_1.jpg',
#  'resources/data/Negative/15047.jpg',
#  'resources/data/Positive/15048_1.jpg',
#  'resources/data/Negative/15048.jpg',
#  'resources/data/Positive/15049_1.jpg',
#  'resources/data/Negative/15049.jpg',
#  'resources/data/Positive/15050_1.jpg',
#  'resources/data/Negative/15050.jpg',
#  'resources/data/Positive/15051_1.jpg',
#  'resources/data/Negative/15051.jpg',
#  'resources/data/Positive/15052_1.jpg',
#  'resources/data/Negative/15052.jpg',
#  'resources/data/Positive/15053_1.jpg',
#  'resources/data/Negative/15053.jpg',
#  'resources/data/Positive/15054_1.jpg',
#  'resources/data/Negative/15054.jpg',
#  'resources/data/Positive/15055_1.jpg',
#  'resources/data/Negative/15055.jpg',
#  'resources/data/Positive/15056_1.jpg',
#  'resources/data/Negative/15056.jpg',
#  'resources/data/Positive/15057_1.jpg',
#  'resources/data/Negative/15057.jpg',
#  'resources/data/Positive/15058_1.jpg',
#  'resources/data/Negative/15058.jpg',
#  'resources/data/Positive/15059_1.jpg',
#  'resources/data/Negative/15059.jpg',
#  'resources/data/Positive/15060_1.jpg',
#  'resources/data/Negative/15060.jpg',
#  'resources/data/Positive/15061_1.jpg',
#  'resources/data/Negative/15061.jpg',
#  'resources/data/Positive/15062_1.jpg',
#  'resources/data/Negative/15062.jpg',
#  'resources/data/Positive/15063_1.jpg',
#  'resources/data/Negative/15063.jpg',
#  'resources/data/Positive/15064_1.jpg',
#  'resources/data/Negative/15064.jpg',
#  'resources/data/Positive/15065_1.jpg',
#  'resources/data/Negative/15065.jpg',
#  'resources/data/Positive/15066_1.jpg',
#  'resources/data/Negative/15066.jpg',
#  'resources/data/Positive/15067_1.jpg',
#  'resources/data/Negative/15067.jpg',
#  'resources/data/Positive/15068_1.jpg',
#  'resources/data/Negative/15068.jpg',
#  'resources/data/Positive/15069_1.jpg',
#  'resources/data/Negative/15069.jpg',
#  'resources/data/Positive/15070_1.jpg',
#  'resources/data/Negative/15070.jpg',
#  'resources/data/Positive/15071_1.jpg',
#  'resources/data/Negative/15071.jpg',
#  'resources/data/Positive/15072_1.jpg',
#  'resources/data/Negative/15072.jpg',
#  'resources/data/Positive/15073_1.jpg',
#  'resources/data/Negative/15073.jpg',
#  'resources/data/Positive/15074_1.jpg',
#  'resources/data/Negative/15074.jpg',
#  'resources/data/Positive/15075_1.jpg',
#  'resources/data/Negative/15075.jpg',
#  'resources/data/Positive/15076_1.jpg',
#  'resources/data/Negative/15076.jpg',
#  'resources/data/Positive/15077_1.jpg',
#  'resources/data/Negative/15077.jpg',
#  'resources/data/Positive/15078_1.jpg',
#  'resources/data/Negative/15078.jpg',
#  'resources/data/Positive/15079_1.jpg',
#  'resources/data/Negative/15079.jpg',
#  'resources/data/Positive/15080_1.jpg',
#  'resources/data/Negative/15080.jpg',
#  'resources/data/Positive/15081_1.jpg',
#  'resources/data/Negative/15081.jpg',
#  'resources/data/Positive/15082_1.jpg',
#  'resources/data/Negative/15082.jpg',
#  'resources/data/Positive/15083_1.jpg',
#  'resources/data/Negative/15083.jpg',
#  'resources/data/Positive/15084_1.jpg',
#  'resources/data/Negative/15084.jpg',
#  'resources/data/Positive/15085_1.jpg',
#  'resources/data/Negative/15085.jpg',
#  'resources/data/Positive/15086_1.jpg',
#  'resources/data/Negative/15086.jpg',
#  'resources/data/Positive/15087_1.jpg',
#  'resources/data/Negative/15087.jpg',
#  'resources/data/Positive/15088_1.jpg',
#  'resources/data/Negative/15088.jpg',
#  'resources/data/Positive/15089_1.jpg',
#  'resources/data/Negative/15089.jpg',
#  'resources/data/Positive/15090_1.jpg',
#  'resources/data/Negative/15090.jpg',
#  'resources/data/Positive/15091_1.jpg',
#  'resources/data/Negative/15091.jpg',
#  'resources/data/Positive/15092_1.jpg',
#  'resources/data/Negative/15092.jpg',
#  'resources/data/Positive/15093_1.jpg',
#  'resources/data/Negative/15093.jpg',
#  'resources/data/Positive/15094_1.jpg',
#  'resources/data/Negative/15094.jpg',
#  'resources/data/Positive/15095_1.jpg',
#  'resources/data/Negative/15095.jpg',
#  'resources/data/Positive/15096_1.jpg',
#  'resources/data/Negative/15096.jpg',
#  'resources/data/Positive/15097_1.jpg',
#  'resources/data/Negative/15097.jpg',
#  'resources/data/Positive/15098_1.jpg',
#  'resources/data/Negative/15098.jpg',
#  'resources/data/Positive/15099_1.jpg',
#  'resources/data/Negative/15099.jpg',
#  'resources/data/Positive/15100_1.jpg',
#  'resources/data/Negative/15100.jpg',
#  'resources/data/Positive/15101_1.jpg',
#  'resources/data/Negative/15101.jpg',
#  'resources/data/Positive/15102_1.jpg',
#  'resources/data/Negative/15102.jpg',
#  'resources/data/Positive/15103_1.jpg',
#  'resources/data/Negative/15103.jpg',
#  'resources/data/Positive/15104_1.jpg',
#  'resources/data/Negative/15104.jpg',
#  'resources/data/Positive/15105_1.jpg',
#  'resources/data/Negative/15105.jpg',
#  'resources/data/Positive/15106_1.jpg',
#  'resources/data/Negative/15106.jpg',
#  'resources/data/Positive/15107_1.jpg',
#  'resources/data/Negative/15107.jpg',
#  'resources/data/Positive/15108_1.jpg',
#  'resources/data/Negative/15108.jpg',
#  'resources/data/Positive/15109_1.jpg',
#  'resources/data/Negative/15109.jpg',
#  'resources/data/Positive/15110_1.jpg',
#  'resources/data/Negative/15110.jpg',
#  'resources/data/Positive/15111_1.jpg',
#  'resources/data/Negative/15111.jpg',
#  'resources/data/Positive/15112_1.jpg',
#  'resources/data/Negative/15112.jpg',
#  'resources/data/Positive/15113_1.jpg',
#  'resources/data/Negative/15113.jpg',
#  'resources/data/Positive/15114_1.jpg',
#  'resources/data/Negative/15114.jpg',
#  'resources/data/Positive/15115_1.jpg',
#  'resources/data/Negative/15115.jpg',
#  'resources/data/Positive/15116_1.jpg',
#  'resources/data/Negative/15116.jpg',
#  'resources/data/Positive/15117_1.jpg',
#  'resources/data/Negative/15117.jpg',
#  'resources/data/Positive/15118_1.jpg',
#  'resources/data/Negative/15118.jpg',
#  'resources/data/Positive/15119_1.jpg',
#  'resources/data/Negative/15119.jpg',
#  'resources/data/Positive/15120_1.jpg',
#  'resources/data/Negative/15120.jpg',
#  'resources/data/Positive/15121_1.jpg',
#  'resources/data/Negative/15121.jpg',
#  'resources/data/Positive/15122_1.jpg',
#  'resources/data/Negative/15122.jpg',
#  'resources/data/Positive/15123_1.jpg',
#  'resources/data/Negative/15123.jpg',
#  'resources/data/Positive/15124_1.jpg',
#  'resources/data/Negative/15124.jpg',
#  'resources/data/Positive/15125_1.jpg',
#  'resources/data/Negative/15125.jpg',
#  'resources/data/Positive/15126_1.jpg',
#  'resources/data/Negative/15126.jpg',
#  'resources/data/Positive/15127_1.jpg',
#  'resources/data/Negative/15127.jpg',
#  'resources/data/Positive/15128_1.jpg',
#  'resources/data/Negative/15128.jpg',
#  'resources/data/Positive/15129_1.jpg',
#  'resources/data/Negative/15129.jpg',
#  'resources/data/Positive/15130_1.jpg',
#  'resources/data/Negative/15130.jpg',
#  'resources/data/Positive/15131_1.jpg',
#  'resources/data/Negative/15131.jpg',
#  'resources/data/Positive/15132_1.jpg',
#  'resources/data/Negative/15132.jpg',
#  'resources/data/Positive/15133_1.jpg',
#  'resources/data/Negative/15133.jpg',
#  'resources/data/Positive/15134_1.jpg',
#  'resources/data/Negative/15134.jpg',
#  'resources/data/Positive/15135_1.jpg',
#  'resources/data/Negative/15135.jpg',
#  'resources/data/Positive/15136_1.jpg',
#  'resources/data/Negative/15136.jpg',
#  'resources/data/Positive/15137_1.jpg',
#  'resources/data/Negative/15137.jpg',
#  'resources/data/Positive/15138_1.jpg',
#  'resources/data/Negative/15138.jpg',
#  'resources/data/Positive/15139_1.jpg',
#  'resources/data/Negative/15139.jpg',
#  'resources/data/Positive/15140_1.jpg',
#  'resources/data/Negative/15140.jpg',
#  'resources/data/Positive/15141_1.jpg',
#  'resources/data/Negative/15141.jpg',
#  'resources/data/Positive/15142_1.jpg',
#  'resources/data/Negative/15142.jpg',
#  'resources/data/Positive/15143_1.jpg',
#  'resources/data/Negative/15143.jpg',
#  'resources/data/Positive/15144_1.jpg',
#  'resources/data/Negative/15144.jpg',
#  'resources/data/Positive/15145_1.jpg',
#  'resources/data/Negative/15145.jpg',
#  'resources/data/Positive/15146_1.jpg',
#  'resources/data/Negative/15146.jpg',
#  'resources/data/Positive/15147_1.jpg',
#  'resources/data/Negative/15147.jpg',
#  'resources/data/Positive/15148_1.jpg',
#  'resources/data/Negative/15148.jpg',
#  'resources/data/Positive/15149_1.jpg',
#  'resources/data/Negative/15149.jpg',
#  'resources/data/Positive/15150_1.jpg',
#  'resources/data/Negative/15150.jpg',
#  'resources/data/Positive/15151_1.jpg',
#  'resources/data/Negative/15151.jpg',
#  'resources/data/Positive/15152_1.jpg',
#  'resources/data/Negative/15152.jpg',
#  'resources/data/Positive/15153_1.jpg',
#  'resources/data/Negative/15153.jpg',
#  'resources/data/Positive/15154_1.jpg',
#  'resources/data/Negative/15154.jpg',
#  'resources/data/Positive/15155_1.jpg',
#  'resources/data/Negative/15155.jpg',
#  'resources/data/Positive/15156_1.jpg',
#  'resources/data/Negative/15156.jpg',
#  'resources/data/Positive/15157_1.jpg',
#  'resources/data/Negative/15157.jpg',
#  'resources/data/Positive/15158_1.jpg',
#  'resources/data/Negative/15158.jpg',
#  'resources/data/Positive/15159_1.jpg',
#  'resources/data/Negative/15159.jpg',
#  'resources/data/Positive/15160_1.jpg',
#  'resources/data/Negative/15160.jpg',
#  'resources/data/Positive/15161_1.jpg',
#  'resources/data/Negative/15161.jpg',
#  'resources/data/Positive/15162_1.jpg',
#  'resources/data/Negative/15162.jpg',
#  'resources/data/Positive/15163_1.jpg',
#  'resources/data/Negative/15163.jpg',
#  'resources/data/Positive/15164_1.jpg',
#  'resources/data/Negative/15164.jpg',
#  'resources/data/Positive/15165_1.jpg',
#  'resources/data/Negative/15165.jpg',
#  'resources/data/Positive/15166_1.jpg',
#  'resources/data/Negative/15166.jpg',
#  'resources/data/Positive/15167_1.jpg',
#  'resources/data/Negative/15167.jpg',
#  'resources/data/Positive/15168_1.jpg',
#  'resources/data/Negative/15168.jpg',
#  'resources/data/Positive/15169_1.jpg',
#  'resources/data/Negative/15169.jpg',
#  'resources/data/Positive/15170_1.jpg',
#  'resources/data/Negative/15170.jpg',
#  'resources/data/Positive/15171_1.jpg',
#  'resources/data/Negative/15171.jpg',
#  'resources/data/Positive/15172_1.jpg',
#  'resources/data/Negative/15172.jpg',
#  'resources/data/Positive/15173_1.jpg',
#  'resources/data/Negative/15173.jpg',
#  'resources/data/Positive/15174_1.jpg',
#  'resources/data/Negative/15174.jpg',
#  'resources/data/Positive/15175_1.jpg',
#  'resources/data/Negative/15175.jpg',
#  'resources/data/Positive/15176_1.jpg',
#  'resources/data/Negative/15176.jpg',
#  'resources/data/Positive/15177_1.jpg',
#  'resources/data/Negative/15177.jpg',
#  'resources/data/Positive/15178_1.jpg',
#  'resources/data/Negative/15178.jpg',
#  'resources/data/Positive/15179_1.jpg',
#  'resources/data/Negative/15179.jpg',
#  'resources/data/Positive/15180_1.jpg',
#  'resources/data/Negative/15180.jpg',
#  'resources/data/Positive/15181_1.jpg',
#  'resources/data/Negative/15181.jpg',
#  'resources/data/Positive/15182_1.jpg',
#  'resources/data/Negative/15182.jpg',
#  'resources/data/Positive/15183_1.jpg',
#  'resources/data/Negative/15183.jpg',
#  'resources/data/Positive/15184_1.jpg',
#  'resources/data/Negative/15184.jpg',
#  'resources/data/Positive/15185_1.jpg',
#  'resources/data/Negative/15185.jpg',
#  'resources/data/Positive/15186_1.jpg',
#  'resources/data/Negative/15186.jpg',
#  'resources/data/Positive/15187_1.jpg',
#  'resources/data/Negative/15187.jpg',
#  'resources/data/Positive/15188_1.jpg',
#  'resources/data/Negative/15188.jpg',
#  'resources/data/Positive/15189_1.jpg',
#  'resources/data/Negative/15189.jpg',
#  'resources/data/Positive/15190_1.jpg',
#  'resources/data/Negative/15190.jpg',
#  'resources/data/Positive/15191_1.jpg',
#  'resources/data/Negative/15191.jpg',
#  'resources/data/Positive/15192_1.jpg',
#  'resources/data/Negative/15192.jpg',
#  'resources/data/Positive/15193_1.jpg',
#  'resources/data/Negative/15193.jpg',
#  'resources/data/Positive/15194_1.jpg',
#  'resources/data/Negative/15194.jpg',
#  'resources/data/Positive/15195_1.jpg',
#  'resources/data/Negative/15195.jpg',
#  'resources/data/Positive/15196_1.jpg',
#  'resources/data/Negative/15196.jpg',
#  'resources/data/Positive/15197_1.jpg',
#  'resources/data/Negative/15197.jpg',
#  'resources/data/Positive/15198_1.jpg',
#  'resources/data/Negative/15198.jpg',
#  'resources/data/Positive/15199_1.jpg',
#  'resources/data/Negative/15199.jpg',
#  'resources/data/Positive/15200_1.jpg',
#  'resources/data/Negative/15200.jpg',
#  'resources/data/Positive/15201_1.jpg',
#  'resources/data/Negative/15201.jpg',
#  'resources/data/Positive/15202_1.jpg',
#  'resources/data/Negative/15202.jpg',
#  'resources/data/Positive/15203_1.jpg',
#  'resources/data/Negative/15203.jpg',
#  'resources/data/Positive/15204_1.jpg',
#  'resources/data/Negative/15204.jpg',
#  'resources/data/Positive/15205_1.jpg',
#  'resources/data/Negative/15205.jpg',
#  'resources/data/Positive/15206_1.jpg',
#  'resources/data/Negative/15206.jpg',
#  'resources/data/Positive/15207_1.jpg',
#  'resources/data/Negative/15207.jpg',
#  'resources/data/Positive/15208_1.jpg',
#  'resources/data/Negative/15208.jpg',
#  'resources/data/Positive/15209_1.jpg',
#  'resources/data/Negative/15209.jpg',
#  'resources/data/Positive/15210_1.jpg',
#  'resources/data/Negative/15210.jpg',
#  'resources/data/Positive/15211_1.jpg',
#  'resources/data/Negative/15211.jpg',
#  'resources/data/Positive/15212_1.jpg',
#  'resources/data/Negative/15212.jpg',
#  'resources/data/Positive/15213_1.jpg',
#  'resources/data/Negative/15213.jpg',
#  'resources/data/Positive/15214_1.jpg',
#  'resources/data/Negative/15214.jpg',
#  'resources/data/Positive/15215_1.jpg',
#  'resources/data/Negative/15215.jpg',
#  'resources/data/Positive/15216_1.jpg',
#  'resources/data/Negative/15216.jpg',
#  'resources/data/Positive/15217_1.jpg',
#  'resources/data/Negative/15217.jpg',
#  'resources/data/Positive/15218_1.jpg',
#  'resources/data/Negative/15218.jpg',
#  'resources/data/Positive/15219_1.jpg',
#  'resources/data/Negative/15219.jpg',
#  'resources/data/Positive/15220_1.jpg',
#  'resources/data/Negative/15220.jpg',
#  'resources/data/Positive/15221_1.jpg',
#  'resources/data/Negative/15221.jpg',
#  'resources/data/Positive/15222_1.jpg',
#  'resources/data/Negative/15222.jpg',
#  'resources/data/Positive/15223_1.jpg',
#  'resources/data/Negative/15223.jpg',
#  'resources/data/Positive/15224_1.jpg',
#  'resources/data/Negative/15224.jpg',
#  'resources/data/Positive/15225_1.jpg',
#  'resources/data/Negative/15225.jpg',
#  'resources/data/Positive/15226_1.jpg',
#  'resources/data/Negative/15226.jpg',
#  'resources/data/Positive/15227_1.jpg',
#  'resources/data/Negative/15227.jpg',
#  'resources/data/Positive/15228_1.jpg',
#  'resources/data/Negative/15228.jpg',
#  'resources/data/Positive/15229_1.jpg',
#  'resources/data/Negative/15229.jpg',
#  'resources/data/Positive/15230_1.jpg',
#  'resources/data/Negative/15230.jpg',
#  'resources/data/Positive/15231_1.jpg',
#  'resources/data/Negative/15231.jpg',
#  'resources/data/Positive/15232_1.jpg',
#  'resources/data/Negative/15232.jpg',
#  'resources/data/Positive/15233_1.jpg',
#  'resources/data/Negative/15233.jpg',
#  'resources/data/Positive/15234_1.jpg',
#  'resources/data/Negative/15234.jpg',
#  'resources/data/Positive/15235_1.jpg',
#  'resources/data/Negative/15235.jpg',
#  'resources/data/Positive/15236_1.jpg',
#  'resources/data/Negative/15236.jpg',
#  'resources/data/Positive/15237_1.jpg',
#  'resources/data/Negative/15237.jpg',
#  'resources/data/Positive/15238_1.jpg',
#  'resources/data/Negative/15238.jpg',
#  'resources/data/Positive/15239_1.jpg',
#  'resources/data/Negative/15239.jpg',
#  'resources/data/Positive/15240_1.jpg',
#  'resources/data/Negative/15240.jpg',
#  'resources/data/Positive/15241_1.jpg',
#  'resources/data/Negative/15241.jpg',
#  'resources/data/Positive/15242_1.jpg',
#  'resources/data/Negative/15242.jpg',
#  'resources/data/Positive/15243_1.jpg',
#  'resources/data/Negative/15243.jpg',
#  'resources/data/Positive/15244_1.jpg',
#  'resources/data/Negative/15244.jpg',
#  'resources/data/Positive/15245_1.jpg',
#  'resources/data/Negative/15245.jpg',
#  'resources/data/Positive/15246_1.jpg',
#  'resources/data/Negative/15246.jpg',
#  'resources/data/Positive/15247_1.jpg',
#  'resources/data/Negative/15247.jpg',
#  'resources/data/Positive/15248_1.jpg',
#  'resources/data/Negative/15248.jpg',
#  'resources/data/Positive/15249_1.jpg',
#  'resources/data/Negative/15249.jpg',
#  'resources/data/Positive/15250_1.jpg',
#  'resources/data/Negative/15250.jpg',
#  'resources/data/Positive/15251_1.jpg',
#  'resources/data/Negative/15251.jpg',
#  'resources/data/Positive/15252_1.jpg',
#  'resources/data/Negative/15252.jpg',
#  'resources/data/Positive/15253_1.jpg',
#  'resources/data/Negative/15253.jpg',
#  'resources/data/Positive/15254_1.jpg',
#  'resources/data/Negative/15254.jpg',
#  'resources/data/Positive/15255_1.jpg',
#  'resources/data/Negative/15255.jpg',
#  'resources/data/Positive/15256_1.jpg',
#  'resources/data/Negative/15256.jpg',
#  'resources/data/Positive/15257_1.jpg',
#  'resources/data/Negative/15257.jpg',
#  'resources/data/Positive/15258_1.jpg',
#  'resources/data/Negative/15258.jpg',
#  'resources/data/Positive/15259_1.jpg',
#  'resources/data/Negative/15259.jpg',
#  'resources/data/Positive/15260_1.jpg',
#  'resources/data/Negative/15260.jpg',
#  'resources/data/Positive/15261_1.jpg',
#  'resources/data/Negative/15261.jpg',
#  'resources/data/Positive/15262_1.jpg',
#  'resources/data/Negative/15262.jpg',
#  'resources/data/Positive/15263_1.jpg',
#  'resources/data/Negative/15263.jpg',
#  'resources/data/Positive/15264_1.jpg',
#  'resources/data/Negative/15264.jpg',
#  'resources/data/Positive/15265_1.jpg',
#  'resources/data/Negative/15265.jpg',
#  'resources/data/Positive/15266_1.jpg',
#  'resources/data/Negative/15266.jpg',
#  'resources/data/Positive/15267_1.jpg',
#  'resources/data/Negative/15267.jpg',
#  'resources/data/Positive/15268_1.jpg',
#  'resources/data/Negative/15268.jpg',
#  'resources/data/Positive/15269_1.jpg',
#  'resources/data/Negative/15269.jpg',
#  'resources/data/Positive/15270_1.jpg',
#  'resources/data/Negative/15270.jpg',
#  'resources/data/Positive/15271_1.jpg',
#  'resources/data/Negative/15271.jpg',
#  'resources/data/Positive/15272_1.jpg',
#  'resources/data/Negative/15272.jpg',
#  'resources/data/Positive/15273_1.jpg',
#  'resources/data/Negative/15273.jpg',
#  'resources/data/Positive/15274_1.jpg',
#  'resources/data/Negative/15274.jpg',
#  'resources/data/Positive/15275_1.jpg',
#  'resources/data/Negative/15275.jpg',
#  'resources/data/Positive/15276_1.jpg',
#  'resources/data/Negative/15276.jpg',
#  'resources/data/Positive/15277_1.jpg',
#  'resources/data/Negative/15277.jpg',
#  'resources/data/Positive/15278_1.jpg',
#  'resources/data/Negative/15278.jpg',
#  'resources/data/Positive/15279_1.jpg',
#  'resources/data/Negative/15279.jpg',
#  'resources/data/Positive/15280_1.jpg',
#  'resources/data/Negative/15280.jpg',
#  'resources/data/Positive/15281_1.jpg',
#  'resources/data/Negative/15281.jpg',
#  'resources/data/Positive/15282_1.jpg',
#  'resources/data/Negative/15282.jpg',
#  'resources/data/Positive/15283_1.jpg',
#  'resources/data/Negative/15283.jpg',
#  'resources/data/Positive/15284_1.jpg',
#  'resources/data/Negative/15284.jpg',
#  'resources/data/Positive/15285_1.jpg',
#  'resources/data/Negative/15285.jpg',
#  'resources/data/Positive/15286_1.jpg',
#  'resources/data/Negative/15286.jpg',
#  'resources/data/Positive/15287_1.jpg',
#  'resources/data/Negative/15287.jpg',
#  'resources/data/Positive/15288_1.jpg',
#  'resources/data/Negative/15288.jpg',
#  'resources/data/Positive/15289_1.jpg',
#  'resources/data/Negative/15289.jpg',
#  'resources/data/Positive/15290_1.jpg',
#  'resources/data/Negative/15290.jpg',
#  'resources/data/Positive/15291_1.jpg',
#  'resources/data/Negative/15291.jpg',
#  'resources/data/Positive/15292_1.jpg',
#  'resources/data/Negative/15292.jpg',
#  'resources/data/Positive/15293_1.jpg',
#  'resources/data/Negative/15293.jpg',
#  'resources/data/Positive/15294_1.jpg',
#  'resources/data/Negative/15294.jpg',
#  'resources/data/Positive/15295_1.jpg',
#  'resources/data/Negative/15295.jpg',
#  'resources/data/Positive/15296_1.jpg',
#  'resources/data/Negative/15296.jpg',
#  'resources/data/Positive/15297_1.jpg',
#  'resources/data/Negative/15297.jpg',
#  'resources/data/Positive/15298_1.jpg',
#  'resources/data/Negative/15298.jpg',
#  'resources/data/Positive/15299_1.jpg',
#  'resources/data/Negative/15299.jpg',
#  'resources/data/Positive/15300_1.jpg',
#  'resources/data/Negative/15300.jpg',
#  'resources/data/Positive/15301_1.jpg',
#  'resources/data/Negative/15301.jpg',
#  'resources/data/Positive/15302_1.jpg',
#  'resources/data/Negative/15302.jpg',
#  'resources/data/Positive/15303_1.jpg',
#  'resources/data/Negative/15303.jpg',
#  'resources/data/Positive/15304_1.jpg',
#  'resources/data/Negative/15304.jpg',
#  'resources/data/Positive/15305_1.jpg',
#  'resources/data/Negative/15305.jpg',
#  'resources/data/Positive/15306_1.jpg',
#  'resources/data/Negative/15306.jpg',
#  'resources/data/Positive/15307_1.jpg',
#  'resources/data/Negative/15307.jpg',
#  'resources/data/Positive/15308_1.jpg',
#  'resources/data/Negative/15308.jpg',
#  'resources/data/Positive/15309_1.jpg',
#  'resources/data/Negative/15309.jpg',
#  'resources/data/Positive/15310_1.jpg',
#  'resources/data/Negative/15310.jpg',
#  'resources/data/Positive/15311_1.jpg',
#  'resources/data/Negative/15311.jpg',
#  'resources/data/Positive/15312_1.jpg',
#  'resources/data/Negative/15312.jpg',
#  'resources/data/Positive/15313_1.jpg',
#  'resources/data/Negative/15313.jpg',
#  'resources/data/Positive/15314_1.jpg',
#  'resources/data/Negative/15314.jpg',
#  'resources/data/Positive/15315_1.jpg',
#  'resources/data/Negative/15315.jpg',
#  'resources/data/Positive/15316_1.jpg',
#  'resources/data/Negative/15316.jpg',
#  'resources/data/Positive/15317_1.jpg',
#  'resources/data/Negative/15317.jpg',
#  'resources/data/Positive/15318_1.jpg',
#  'resources/data/Negative/15318.jpg',
#  'resources/data/Positive/15319_1.jpg',
#  'resources/data/Negative/15319.jpg',
#  'resources/data/Positive/15320_1.jpg',
#  'resources/data/Negative/15320.jpg',
#  'resources/data/Positive/15321_1.jpg',
#  'resources/data/Negative/15321.jpg',
#  'resources/data/Positive/15322_1.jpg',
#  'resources/data/Negative/15322.jpg',
#  'resources/data/Positive/15323_1.jpg',
#  'resources/data/Negative/15323.jpg',
#  'resources/data/Positive/15324_1.jpg',
#  'resources/data/Negative/15324.jpg',
#  'resources/data/Positive/15325_1.jpg',
#  'resources/data/Negative/15325.jpg',
#  'resources/data/Positive/15326_1.jpg',
#  'resources/data/Negative/15326.jpg',
#  'resources/data/Positive/15327_1.jpg',
#  'resources/data/Negative/15327.jpg',
#  'resources/data/Positive/15328_1.jpg',
#  'resources/data/Negative/15328.jpg',
#  'resources/data/Positive/15329_1.jpg',
#  'resources/data/Negative/15329.jpg',
#  'resources/data/Positive/15330_1.jpg',
#  'resources/data/Negative/15330.jpg',
#  'resources/data/Positive/15331_1.jpg',
#  'resources/data/Negative/15331.jpg',
#  'resources/data/Positive/15332_1.jpg',
#  'resources/data/Negative/15332.jpg',
#  'resources/data/Positive/15333_1.jpg',
#  'resources/data/Negative/15333.jpg',
#  'resources/data/Positive/15334_1.jpg',
#  'resources/data/Negative/15334.jpg',
#  'resources/data/Positive/15335_1.jpg',
#  'resources/data/Negative/15335.jpg',
#  'resources/data/Positive/15336_1.jpg',
#  'resources/data/Negative/15336.jpg',
#  'resources/data/Positive/15337_1.jpg',
#  'resources/data/Negative/15337.jpg',
#  'resources/data/Positive/15338_1.jpg',
#  'resources/data/Negative/15338.jpg',
#  'resources/data/Positive/15339_1.jpg',
#  'resources/data/Negative/15339.jpg',
#  'resources/data/Positive/15340_1.jpg',
#  'resources/data/Negative/15340.jpg',
#  'resources/data/Positive/15341_1.jpg',
#  'resources/data/Negative/15341.jpg',
#  'resources/data/Positive/15342_1.jpg',
#  'resources/data/Negative/15342.jpg',
#  'resources/data/Positive/15343_1.jpg',
#  'resources/data/Negative/15343.jpg',
#  'resources/data/Positive/15344_1.jpg',
#  'resources/data/Negative/15344.jpg',
#  'resources/data/Positive/15345_1.jpg',
#  'resources/data/Negative/15345.jpg',
#  'resources/data/Positive/15346_1.jpg',
#  'resources/data/Negative/15346.jpg',
#  'resources/data/Positive/15347_1.jpg',
#  'resources/data/Negative/15347.jpg',
#  'resources/data/Positive/15348_1.jpg',
#  'resources/data/Negative/15348.jpg',
#  'resources/data/Positive/15349_1.jpg',
#  'resources/data/Negative/15349.jpg',
#  'resources/data/Positive/15350_1.jpg',
#  'resources/data/Negative/15350.jpg',
#  'resources/data/Positive/15351_1.jpg',
#  'resources/data/Negative/15351.jpg',
#  'resources/data/Positive/15352_1.jpg',
#  'resources/data/Negative/15352.jpg',
#  'resources/data/Positive/15353_1.jpg',
#  'resources/data/Negative/15353.jpg',
#  'resources/data/Positive/15354_1.jpg',
#  'resources/data/Negative/15354.jpg',
#  'resources/data/Positive/15355_1.jpg',
#  'resources/data/Negative/15355.jpg',
#  'resources/data/Positive/15356_1.jpg',
#  'resources/data/Negative/15356.jpg',
#  'resources/data/Positive/15357_1.jpg',
#  'resources/data/Negative/15357.jpg',
#  'resources/data/Positive/15358_1.jpg',
#  'resources/data/Negative/15358.jpg',
#  'resources/data/Positive/15359_1.jpg',
#  'resources/data/Negative/15359.jpg',
#  'resources/data/Positive/15360_1.jpg',
#  'resources/data/Negative/15360.jpg',
#  'resources/data/Positive/15361_1.jpg',
#  'resources/data/Negative/15361.jpg',
#  'resources/data/Positive/15362_1.jpg',
#  'resources/data/Negative/15362.jpg',
#  'resources/data/Positive/15363_1.jpg',
#  'resources/data/Negative/15363.jpg',
#  'resources/data/Positive/15364_1.jpg',
#  'resources/data/Negative/15364.jpg',
#  'resources/data/Positive/15365_1.jpg',
#  'resources/data/Negative/15365.jpg',
#  'resources/data/Positive/15366_1.jpg',
#  'resources/data/Negative/15366.jpg',
#  'resources/data/Positive/15367_1.jpg',
#  'resources/data/Negative/15367.jpg',
#  'resources/data/Positive/15368_1.jpg',
#  'resources/data/Negative/15368.jpg',
#  'resources/data/Positive/15369_1.jpg',
#  'resources/data/Negative/15369.jpg',
#  'resources/data/Positive/15370_1.jpg',
#  'resources/data/Negative/15370.jpg',
#  'resources/data/Positive/15371_1.jpg',
#  'resources/data/Negative/15371.jpg',
#  'resources/data/Positive/15372_1.jpg',
#  'resources/data/Negative/15372.jpg',
#  'resources/data/Positive/15373_1.jpg',
#  'resources/data/Negative/15373.jpg',
#  'resources/data/Positive/15374_1.jpg',
#  'resources/data/Negative/15374.jpg',
#  'resources/data/Positive/15375_1.jpg',
#  'resources/data/Negative/15375.jpg',
#  'resources/data/Positive/15376_1.jpg',
#  'resources/data/Negative/15376.jpg',
#  'resources/data/Positive/15377_1.jpg',
#  'resources/data/Negative/15377.jpg',
#  'resources/data/Positive/15378_1.jpg',
#  'resources/data/Negative/15378.jpg',
#  'resources/data/Positive/15379_1.jpg',
#  'resources/data/Negative/15379.jpg',
#  'resources/data/Positive/15380_1.jpg',
#  'resources/data/Negative/15380.jpg',
#  'resources/data/Positive/15381_1.jpg',
#  'resources/data/Negative/15381.jpg',
#  'resources/data/Positive/15382_1.jpg',
#  'resources/data/Negative/15382.jpg',
#  'resources/data/Positive/15383_1.jpg',
#  'resources/data/Negative/15383.jpg',
#  'resources/data/Positive/15384_1.jpg',
#  'resources/data/Negative/15384.jpg',
#  'resources/data/Positive/15385_1.jpg',
#  'resources/data/Negative/15385.jpg',
#  'resources/data/Positive/15386_1.jpg',
#  'resources/data/Negative/15386.jpg',
#  'resources/data/Positive/15387_1.jpg',
#  'resources/data/Negative/15387.jpg',
#  'resources/data/Positive/15388_1.jpg',
#  'resources/data/Negative/15388.jpg',
#  'resources/data/Positive/15389_1.jpg',
#  'resources/data/Negative/15389.jpg',
#  'resources/data/Positive/15390_1.jpg',
#  'resources/data/Negative/15390.jpg',
#  'resources/data/Positive/15391_1.jpg',
#  'resources/data/Negative/15391.jpg',
#  'resources/data/Positive/15392_1.jpg',
#  'resources/data/Negative/15392.jpg',
#  'resources/data/Positive/15393_1.jpg',
#  'resources/data/Negative/15393.jpg',
#  'resources/data/Positive/15394_1.jpg',
#  'resources/data/Negative/15394.jpg',
#  'resources/data/Positive/15395_1.jpg',
#  'resources/data/Negative/15395.jpg',
#  'resources/data/Positive/15396_1.jpg',
#  'resources/data/Negative/15396.jpg',
#  'resources/data/Positive/15397_1.jpg',
#  'resources/data/Negative/15397.jpg',
#  'resources/data/Positive/15398_1.jpg',
#  'resources/data/Negative/15398.jpg',
#  'resources/data/Positive/15399_1.jpg',
#  'resources/data/Negative/15399.jpg',
#  'resources/data/Positive/15400_1.jpg',
#  'resources/data/Negative/15400.jpg',
#  'resources/data/Positive/15401_1.jpg',
#  'resources/data/Negative/15401.jpg',
#  'resources/data/Positive/15402_1.jpg',
#  'resources/data/Negative/15402.jpg',
#  'resources/data/Positive/15403_1.jpg',
#  'resources/data/Negative/15403.jpg',
#  'resources/data/Positive/15404_1.jpg',
#  'resources/data/Negative/15404.jpg',
#  'resources/data/Positive/15405_1.jpg',
#  'resources/data/Negative/15405.jpg',
#  'resources/data/Positive/15406_1.jpg',
#  'resources/data/Negative/15406.jpg',
#  'resources/data/Positive/15407_1.jpg',
#  'resources/data/Negative/15407.jpg',
#  'resources/data/Positive/15408_1.jpg',
#  'resources/data/Negative/15408.jpg',
#  'resources/data/Positive/15409_1.jpg',
#  'resources/data/Negative/15409.jpg',
#  'resources/data/Positive/15410_1.jpg',
#  'resources/data/Negative/15410.jpg',
#  'resources/data/Positive/15411_1.jpg',
#  'resources/data/Negative/15411.jpg',
#  'resources/data/Positive/15412_1.jpg',
#  'resources/data/Negative/15412.jpg',
#  'resources/data/Positive/15413_1.jpg',
#  'resources/data/Negative/15413.jpg',
#  'resources/data/Positive/15414_1.jpg',
#  'resources/data/Negative/15414.jpg',
#  'resources/data/Positive/15415_1.jpg',
#  'resources/data/Negative/15415.jpg',
#  'resources/data/Positive/15416_1.jpg',
#  'resources/data/Negative/15416.jpg',
#  'resources/data/Positive/15417_1.jpg',
#  'resources/data/Negative/15417.jpg',
#  'resources/data/Positive/15418_1.jpg',
#  'resources/data/Negative/15418.jpg',
#  'resources/data/Positive/15419_1.jpg',
#  'resources/data/Negative/15419.jpg',
#  'resources/data/Positive/15420_1.jpg',
#  'resources/data/Negative/15420.jpg',
#  'resources/data/Positive/15421_1.jpg',
#  'resources/data/Negative/15421.jpg',
#  'resources/data/Positive/15422_1.jpg',
#  'resources/data/Negative/15422.jpg',
#  'resources/data/Positive/15423_1.jpg',
#  'resources/data/Negative/15423.jpg',
#  'resources/data/Positive/15424_1.jpg',
#  'resources/data/Negative/15424.jpg',
#  'resources/data/Positive/15425_1.jpg',
#  'resources/data/Negative/15425.jpg',
#  'resources/data/Positive/15426_1.jpg',
#  'resources/data/Negative/15426.jpg',
#  'resources/data/Positive/15427_1.jpg',
#  'resources/data/Negative/15427.jpg',
#  'resources/data/Positive/15428_1.jpg',
#  'resources/data/Negative/15428.jpg',
#  'resources/data/Positive/15429_1.jpg',
#  'resources/data/Negative/15429.jpg',
#  'resources/data/Positive/15430_1.jpg',
#  'resources/data/Negative/15430.jpg',
#  'resources/data/Positive/15431_1.jpg',
#  'resources/data/Negative/15431.jpg',
#  'resources/data/Positive/15432_1.jpg',
#  'resources/data/Negative/15432.jpg',
#  'resources/data/Positive/15433_1.jpg',
#  'resources/data/Negative/15433.jpg',
#  'resources/data/Positive/15434_1.jpg',
#  'resources/data/Negative/15434.jpg',
#  'resources/data/Positive/15435_1.jpg',
#  'resources/data/Negative/15435.jpg',
#  'resources/data/Positive/15436_1.jpg',
#  'resources/data/Negative/15436.jpg',
#  'resources/data/Positive/15437_1.jpg',
#  'resources/data/Negative/15437.jpg',
#  'resources/data/Positive/15438_1.jpg',
#  'resources/data/Negative/15438.jpg',
#  'resources/data/Positive/15439_1.jpg',
#  'resources/data/Negative/15439.jpg',
#  'resources/data/Positive/15440_1.jpg',
#  'resources/data/Negative/15440.jpg',
#  'resources/data/Positive/15441_1.jpg',
#  'resources/data/Negative/15441.jpg',
#  'resources/data/Positive/15442_1.jpg',
#  'resources/data/Negative/15442.jpg',
#  'resources/data/Positive/15443_1.jpg',
#  'resources/data/Negative/15443.jpg',
#  'resources/data/Positive/15444_1.jpg',
#  'resources/data/Negative/15444.jpg',
#  'resources/data/Positive/15445_1.jpg',
#  'resources/data/Negative/15445.jpg',
#  'resources/data/Positive/15446_1.jpg',
#  'resources/data/Negative/15446.jpg',
#  'resources/data/Positive/15447_1.jpg',
#  'resources/data/Negative/15447.jpg',
#  'resources/data/Positive/15448_1.jpg',
#  'resources/data/Negative/15448.jpg',
#  'resources/data/Positive/15449_1.jpg',
#  'resources/data/Negative/15449.jpg',
#  'resources/data/Positive/15450_1.jpg',
#  'resources/data/Negative/15450.jpg',
#  'resources/data/Positive/15451_1.jpg',
#  'resources/data/Negative/15451.jpg',
#  'resources/data/Positive/15452_1.jpg',
#  'resources/data/Negative/15452.jpg',
#  'resources/data/Positive/15453_1.jpg',
#  'resources/data/Negative/15453.jpg',
#  'resources/data/Positive/15454_1.jpg',
#  'resources/data/Negative/15454.jpg',
#  'resources/data/Positive/15455_1.jpg',
#  'resources/data/Negative/15455.jpg',
#  'resources/data/Positive/15456_1.jpg',
#  'resources/data/Negative/15456.jpg',
#  'resources/data/Positive/15457_1.jpg',
#  'resources/data/Negative/15457.jpg',
#  'resources/data/Positive/15458_1.jpg',
#  'resources/data/Negative/15458.jpg',
#  'resources/data/Positive/15459_1.jpg',
#  'resources/data/Negative/15459.jpg',
#  'resources/data/Positive/15460_1.jpg',
#  'resources/data/Negative/15460.jpg',
#  'resources/data/Positive/15461_1.jpg',
#  'resources/data/Negative/15461.jpg',
#  'resources/data/Positive/15462_1.jpg',
#  'resources/data/Negative/15462.jpg',
#  'resources/data/Positive/15463_1.jpg',
#  'resources/data/Negative/15463.jpg',
#  'resources/data/Positive/15464_1.jpg',
#  'resources/data/Negative/15464.jpg',
#  'resources/data/Positive/15465_1.jpg',
#  'resources/data/Negative/15465.jpg',
#  'resources/data/Positive/15466_1.jpg',
#  'resources/data/Negative/15466.jpg',
#  'resources/data/Positive/15467_1.jpg',
#  'resources/data/Negative/15467.jpg',
#  'resources/data/Positive/15468_1.jpg',
#  'resources/data/Negative/15468.jpg',
#  'resources/data/Positive/15469_1.jpg',
#  'resources/data/Negative/15469.jpg',
#  'resources/data/Positive/15470_1.jpg',
#  'resources/data/Negative/15470.jpg',
#  'resources/data/Positive/15471_1.jpg',
#  'resources/data/Negative/15471.jpg',
#  'resources/data/Positive/15472_1.jpg',
#  'resources/data/Negative/15472.jpg',
#  'resources/data/Positive/15473_1.jpg',
#  'resources/data/Negative/15473.jpg',
#  'resources/data/Positive/15474_1.jpg',
#  'resources/data/Negative/15474.jpg',
#  'resources/data/Positive/15475_1.jpg',
#  'resources/data/Negative/15475.jpg',
#  'resources/data/Positive/15476_1.jpg',
#  'resources/data/Negative/15476.jpg',
#  'resources/data/Positive/15477_1.jpg',
#  'resources/data/Negative/15477.jpg',
#  'resources/data/Positive/15478_1.jpg',
#  'resources/data/Negative/15478.jpg',
#  'resources/data/Positive/15479_1.jpg',
#  'resources/data/Negative/15479.jpg',
#  'resources/data/Positive/15480_1.jpg',
#  'resources/data/Negative/15480.jpg',
#  'resources/data/Positive/15481_1.jpg',
#  'resources/data/Negative/15481.jpg',
#  'resources/data/Positive/15482_1.jpg',
#  'resources/data/Negative/15482.jpg',
#  'resources/data/Positive/15483_1.jpg',
#  'resources/data/Negative/15483.jpg',
#  'resources/data/Positive/15484_1.jpg',
#  'resources/data/Negative/15484.jpg',
#  'resources/data/Positive/15485_1.jpg',
#  'resources/data/Negative/15485.jpg',
#  'resources/data/Positive/15486_1.jpg',
#  'resources/data/Negative/15486.jpg',
#  'resources/data/Positive/15487_1.jpg',
#  'resources/data/Negative/15487.jpg',
#  'resources/data/Positive/15488_1.jpg',
#  'resources/data/Negative/15488.jpg',
#  'resources/data/Positive/15489_1.jpg',
#  'resources/data/Negative/15489.jpg',
#  'resources/data/Positive/15490_1.jpg',
#  'resources/data/Negative/15490.jpg',
#  'resources/data/Positive/15491_1.jpg',
#  'resources/data/Negative/15491.jpg',
#  'resources/data/Positive/15492_1.jpg',
#  'resources/data/Negative/15492.jpg',
#  'resources/data/Positive/15493_1.jpg',
#  'resources/data/Negative/15493.jpg',
#  'resources/data/Positive/15494_1.jpg',
#  'resources/data/Negative/15494.jpg',
#  'resources/data/Positive/15495_1.jpg',
#  'resources/data/Negative/15495.jpg',
#  'resources/data/Positive/15496_1.jpg',
#  'resources/data/Negative/15496.jpg',
#  'resources/data/Positive/15497_1.jpg',
#  'resources/data/Negative/15497.jpg',
#  'resources/data/Positive/15498_1.jpg',
#  'resources/data/Negative/15498.jpg',
#  'resources/data/Positive/15499_1.jpg',
#  'resources/data/Negative/15499.jpg',
#  'resources/data/Positive/15500_1.jpg',
#  'resources/data/Negative/15500.jpg',
#  ...]

# %%
for y,file in zip(Y, all_files[0:4]):
    print("hola")
    plt.imshow(Image.open(file))
    plt.title("y="+str(y.item()))
    plt.show()

# %% [markdown]
# Just a note the images printed out in question two are the first four training samples.

# %% [markdown]
# <h2 id="data_class">Create a Dataset Class</h2>

# %% [markdown]
# In this section, we will use the previous code to build a dataset class.

# %% [markdown]
# Complete the code to build a Dataset class <code>dataset</code>. As before, make sure the even samples are positive, and the odd samples are negative.  If the parameter <code>train</code> is set to <code>True</code>, use the first 30 000  samples as training data; otherwise, the remaining samples will be used as validation data.

# %%
class CustomDataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="resources/data"
        positive="Positive"
        negative="Negative"

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in  os.listdir(positive_file_path) if file.endswith(".jpg")]
        positive_files.sort()
        negative_files=[os.path.join(negative_file_path,file) for file in  os.listdir(negative_file_path) if file.endswith(".jpg")]
        negative_files.sort()

        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files 
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0
        
        if train:

            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:

            self.Y=self.Y[30000:]
            self.len=len(self.all_files)
    
  
            
     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):

        image=Image.open(self.all_files[idx])
        y=self.Y[idx]

        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y

# %% [markdown]
# <h2 id="Question_4">Question 4</h2>
# <b>Create a Dataset object <code>dataset</code> for the training data, use the following lines of code to print out sample the 10th and  sample 100 (remember zero indexing)  </b>

# %%
dataset = CustomDataset(train=True)
samples = [9, 100]
for sample  in samples:
    plt.imshow(dataset[sample][0])
    plt.xlabel("y="+str(dataset[sample][1].item()))
    plt.title("training data, sample {}".format(int(sample)))
    plt.show()

# %% [markdown]
# We now have all the tools to create a list with the path to each image file.  We use a List Comprehensions  to make the code more compact. We assign it to the variable <code>negative_files</code> , sort it in and display the first three elements:

# %% [markdown]
# <h2 id="Question_5">Question 5</h2>
# <b>Create a Dataset object <code>dataset</code> for the validation  data, use the following lines of code to print out the 16 th and  sample 103 (remember zero indexing)   </b>

# %%
dataset = CustomDataset(train=False)
samples = [14, 101]
for sample  in samples:
    plt.imshow(dataset[sample][0])
    plt.xlabel("y="+str(dataset[sample][1].item()))
    plt.title("validation data, sample {}".format(int(sample)))
    plt.show()

# %% [markdown]
# <h2>About the Authors:</h2>
#  <a href=\"https://www.linkedin.com/in/joseph-s-50398b136/\">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-18  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href=\"https://bigdatauniversity.com/mit-license/\">MIT License</a>
